# %%
import pandas as pd

# %%
df = pd.read_csv("covid19_bigdata_project.csv")

# %%
df
# Out:
#             date           state  confirmed  deaths  recovered  active
# 0     2021-05-10   Uttar Pradesh      860.0    14.0      106.0     740
# 1     2020-05-27           Bihar     3444.0     NaN     2919.0     426
# 2     2021-03-21          Kerala        NaN     NaN       21.0    1106
# 3     2021-06-19  Andhra Pradesh        NaN    14.0      189.0    2544
# 4     2020-07-09  Madhya Pradesh     3556.0     NaN      646.0    2860
# ...          ...             ...        ...     ...        ...     ...
# 4995  2020-11-06  Andhra Pradesh     1729.0    22.0       38.0    1669
# 4996  2020-05-20       Karnataka      340.0   164.0      227.0     -51
# 4997  2021-12-06      Tamil Nadu     2087.0   137.0      255.0    1695
# 4998  2020-07-10     West Bengal     2915.0    26.0        NaN     858
# 4999  2021-12-26             NaN     1646.0   155.0      512.0     979
#
# [5000 rows x 6 columns]

# %%
df = pd.read_csv("covid19_bigdata_project.csv").copy()

# %%
df
# Out:
#             date           state  confirmed  deaths  recovered  active
# 0     2021-05-10   Uttar Pradesh      860.0    14.0      106.0     740
# 1     2020-05-27           Bihar     3444.0     NaN     2919.0     426
# 2     2021-03-21          Kerala        NaN     NaN       21.0    1106
# 3     2021-06-19  Andhra Pradesh        NaN    14.0      189.0    2544
# 4     2020-07-09  Madhya Pradesh     3556.0     NaN      646.0    2860
# ...          ...             ...        ...     ...        ...     ...
# 4995  2020-11-06  Andhra Pradesh     1729.0    22.0       38.0    1669
# 4996  2020-05-20       Karnataka      340.0   164.0      227.0     -51
# 4997  2021-12-06      Tamil Nadu     2087.0   137.0      255.0    1695
# 4998  2020-07-10     West Bengal     2915.0    26.0        NaN     858
# 4999  2021-12-26             NaN     1646.0   155.0      512.0     979
#
# [5000 rows x 6 columns]

# %%
df.head()
# Out:
#          date           state  confirmed  deaths  recovered  active
# 0  2021-05-10   Uttar Pradesh      860.0    14.0      106.0     740
# 1  2020-05-27           Bihar     3444.0     NaN     2919.0     426
# 2  2021-03-21          Kerala        NaN     NaN       21.0    1106
# 3  2021-06-19  Andhra Pradesh        NaN    14.0      189.0    2544
# 4  2020-07-09  Madhya Pradesh     3556.0     NaN      646.0    2860

# %%
df.tail()
# Out:
#             date           state  confirmed  deaths  recovered  active
# 4995  2020-11-06  Andhra Pradesh     1729.0    22.0       38.0    1669
# 4996  2020-05-20       Karnataka      340.0   164.0      227.0     -51
# 4997  2021-12-06      Tamil Nadu     2087.0   137.0      255.0    1695
# 4998  2020-07-10     West Bengal     2915.0    26.0        NaN     858
# 4999  2021-12-26             NaN     1646.0   155.0      512.0     979

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       5000 non-null   object
#  1   state      4729 non-null   object
#  2   confirmed  4462 non-null   float64
#  3   deaths     4493 non-null   float64
#  4   recovered  4510 non-null   float64
#  5   active     5000 non-null   int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 234.5+ KB

# %%
df.describe()
# Out:
#          confirmed       deaths    recovered       active
# count  4462.000000  4493.000000  4510.000000  5000.000000
# mean   2485.834827   100.305586  1220.198448  1158.124200
# std    1451.336965    57.887514  1087.643323  1113.119383
# min       0.000000     0.000000     0.000000  -195.000000
# 25%    1220.000000    49.000000   324.000000   240.000000
# 50%    2493.500000   101.000000   891.500000   844.500000
# 75%    3723.000000   150.000000  1893.750000  1849.000000
# max    4999.000000   199.000000  4948.000000  4905.000000

# %%
df.isnull()
# Out:
#        date  state  confirmed  deaths  recovered  active
# 0     False  False      False   False      False   False
# 1     False  False      False    True      False   False
# 2     False  False       True    True      False   False
# 3     False  False       True   False      False   False
# 4     False  False      False    True      False   False
# ...     ...    ...        ...     ...        ...     ...
# 4995  False  False      False   False      False   False
# 4996  False  False      False   False      False   False
# 4997  False  False      False   False      False   False
# 4998  False  False      False   False       True   False
# 4999  False   True      False   False      False   False
#
# [5000 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# date           0
# state        271
# confirmed    538
# deaths       507
# recovered    490
# active         0
# dtype: int64

# %%
df.shape
# Out:
# (5000, 6)

# %%
df.isnull().sum()
# Out:
# date           0
# state        271
# confirmed    538
# deaths       507
# recovered    490
# active         0
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
df
# Out:
#            date           state  confirmed  deaths  recovered  active
# 0    2021-05-10   Uttar Pradesh      860.0    14.0      106.0     740
# 1    2020-05-27           Bihar     3444.0     NaN     2919.0     426
# 2    2021-03-21          Kerala        NaN     NaN       21.0    1106
# 3    2021-06-19  Andhra Pradesh        NaN    14.0      189.0    2544
# 4    2020-07-09  Madhya Pradesh     3556.0     NaN      646.0    2860
# ...         ...             ...        ...     ...        ...     ...
# 4995 2020-11-06  Andhra Pradesh     1729.0    22.0       38.0    1669
# 4996 2020-05-20       Karnataka      340.0   164.0      227.0     -51
# 4997 2021-12-06      Tamil Nadu     2087.0   137.0      255.0    1695
# 4998 2020-07-10     West Bengal     2915.0    26.0        NaN     858
# 4999 2021-12-26             NaN     1646.0   155.0      512.0     979
#
# [5000 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# date           0
# state        271
# confirmed    538
# deaths       507
# recovered    490
# active         0
# dtype: int64

# %%
df.loc[:, 'confirmed'] = df['confirmed'].fillna(0)

# %%
df
# Out:
#            date           state  confirmed  deaths  recovered  active
# 0    2021-05-10   Uttar Pradesh      860.0    14.0      106.0     740
# 1    2020-05-27           Bihar     3444.0     NaN     2919.0     426
# 2    2021-03-21          Kerala        0.0     NaN       21.0    1106
# 3    2021-06-19  Andhra Pradesh        0.0    14.0      189.0    2544
# 4    2020-07-09  Madhya Pradesh     3556.0     NaN      646.0    2860
# ...         ...             ...        ...     ...        ...     ...
# 4995 2020-11-06  Andhra Pradesh     1729.0    22.0       38.0    1669
# 4996 2020-05-20       Karnataka      340.0   164.0      227.0     -51
# 4997 2021-12-06      Tamil Nadu     2087.0   137.0      255.0    1695
# 4998 2020-07-10     West Bengal     2915.0    26.0        NaN     858
# 4999 2021-12-26             NaN     1646.0   155.0      512.0     979
#
# [5000 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# date           0
# state        271
# confirmed      0
# deaths       507
# recovered    490
# active         0
# dtype: int64

# %%
df.loc[:, 'deaths'] = df['deaths'].fillna(0)

# %%
df
# Out:
#            date           state  confirmed  deaths  recovered  active
# 0    2021-05-10   Uttar Pradesh      860.0    14.0      106.0     740
# 1    2020-05-27           Bihar     3444.0     0.0     2919.0     426
# 2    2021-03-21          Kerala        0.0     0.0       21.0    1106
# 3    2021-06-19  Andhra Pradesh        0.0    14.0      189.0    2544
# 4    2020-07-09  Madhya Pradesh     3556.0     0.0      646.0    2860
# ...         ...             ...        ...     ...        ...     ...
# 4995 2020-11-06  Andhra Pradesh     1729.0    22.0       38.0    1669
# 4996 2020-05-20       Karnataka      340.0   164.0      227.0     -51
# 4997 2021-12-06      Tamil Nadu     2087.0   137.0      255.0    1695
# 4998 2020-07-10     West Bengal     2915.0    26.0        NaN     858
# 4999 2021-12-26             NaN     1646.0   155.0      512.0     979
#
# [5000 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# date           0
# state        271
# confirmed      0
# deaths         0
# recovered    490
# active         0
# dtype: int64

# %%
df.loc[:, 'recovered'] = df['recovered'].fillna(0)

# %%
df
# Out:
#            date           state  confirmed  deaths  recovered  active
# 0    2021-05-10   Uttar Pradesh      860.0    14.0      106.0     740
# 1    2020-05-27           Bihar     3444.0     0.0     2919.0     426
# 2    2021-03-21          Kerala        0.0     0.0       21.0    1106
# 3    2021-06-19  Andhra Pradesh        0.0    14.0      189.0    2544
# 4    2020-07-09  Madhya Pradesh     3556.0     0.0      646.0    2860
# ...         ...             ...        ...     ...        ...     ...
# 4995 2020-11-06  Andhra Pradesh     1729.0    22.0       38.0    1669
# 4996 2020-05-20       Karnataka      340.0   164.0      227.0     -51
# 4997 2021-12-06      Tamil Nadu     2087.0   137.0      255.0    1695
# 4998 2020-07-10     West Bengal     2915.0    26.0        0.0     858
# 4999 2021-12-26             NaN     1646.0   155.0      512.0     979
#
# [5000 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# date           0
# state        271
# confirmed      0
# deaths         0
# recovered      0
# active         0
# dtype: int64

# %%
df['state'] = df['state'].str.strip()

# %%
df
# Out:
#            date           state  confirmed  deaths  recovered  active
# 0    2021-05-10   Uttar Pradesh      860.0    14.0      106.0     740
# 1    2020-05-27           Bihar     3444.0     0.0     2919.0     426
# 2    2021-03-21          Kerala        0.0     0.0       21.0    1106
# 3    2021-06-19  Andhra Pradesh        0.0    14.0      189.0    2544
# 4    2020-07-09  Madhya Pradesh     3556.0     0.0      646.0    2860
# ...         ...             ...        ...     ...        ...     ...
# 4995 2020-11-06  Andhra Pradesh     1729.0    22.0       38.0    1669
# 4996 2020-05-20       Karnataka      340.0   164.0      227.0     -51
# 4997 2021-12-06      Tamil Nadu     2087.0   137.0      255.0    1695
# 4998 2020-07-10     West Bengal     2915.0    26.0        0.0     858
# 4999 2021-12-26             NaN     1646.0   155.0      512.0     979
#
# [5000 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# date           0
# state        271
# confirmed      0
# deaths         0
# recovered      0
# active         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#            date           state  confirmed  deaths  recovered  active
# 0    2021-05-10   Uttar Pradesh      860.0    14.0      106.0     740
# 1    2020-05-27           Bihar     3444.0     0.0     2919.0     426
# 2    2021-03-21          Kerala        0.0     0.0       21.0    1106
# 3    2021-06-19  Andhra Pradesh        0.0    14.0      189.0    2544
# 4    2020-07-09  Madhya Pradesh     3556.0     0.0      646.0    2860
# ...         ...             ...        ...     ...        ...     ...
# 4995 2020-11-06  Andhra Pradesh     1729.0    22.0       38.0    1669
# 4996 2020-05-20       Karnataka      340.0   164.0      227.0     -51
# 4997 2021-12-06      Tamil Nadu     2087.0   137.0      255.0    1695
# 4998 2020-07-10     West Bengal     2915.0    26.0        0.0     858
# 4999 2021-12-26             NaN     1646.0   155.0      512.0     979
#
# [5000 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# date           0
# state        271
# confirmed      0
# deaths         0
# recovered      0
# active         0
# dtype: int64

# %%
df = df[df['state'].notnull()]

# %%
df
# Out:
#            date           state  confirmed  deaths  recovered  active
# 0    2021-05-10   Uttar Pradesh      860.0    14.0      106.0     740
# 1    2020-05-27           Bihar     3444.0     0.0     2919.0     426
# 2    2021-03-21          Kerala        0.0     0.0       21.0    1106
# 3    2021-06-19  Andhra Pradesh        0.0    14.0      189.0    2544
# 4    2020-07-09  Madhya Pradesh     3556.0     0.0      646.0    2860
# ...         ...             ...        ...     ...        ...     ...
# 4994 2020-10-06   Uttar Pradesh     4952.0   177.0     3100.0    1675
# 4995 2020-11-06  Andhra Pradesh     1729.0    22.0       38.0    1669
# 4996 2020-05-20       Karnataka      340.0   164.0      227.0     -51
# 4997 2021-12-06      Tamil Nadu     2087.0   137.0      255.0    1695
# 4998 2020-07-10     West Bengal     2915.0    26.0        0.0     858
#
# [4729 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# date         0
# state        0
# confirmed    0
# deaths       0
# recovered    0
# active       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

statewise = df.groupby('state')['confirmed'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12,7))

bars = plt.bar(statewise.index, statewise.values, color=colors, edgecolor='black', linewidth=1.2)

for i in range(len(statewise)):
    plt.text(i, statewise.iloc[i] + 1000, statewise.iloc[i], ha='center')

plt.title('Top 10 States by Confirmed COVID Cases', fontsize=16, fontweight='bold')
plt.xlabel('State', fontsize=12)
plt.ylabel('Confirmed Cases', fontsize=12)
plt.xticks(rotation=45, fontsize=11)
plt.yticks(fontsize=11)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

plt.plot(maha.index, maha.values, marker='o', color='red', linewidth=2, markersize=6, label='Confirmed Cases')

plt.plot(maha.index[-1], maha.values[-1], 'ro') 
plt.text(maha.index[-1], maha.values[-1]+100, maha.values[-1], ha='center')

plt.title('Date-wise Confirmed Cases Trend in Maharashtra', fontsize=16, fontweight='bold')
plt.xlabel('Date', fontsize=12)
plt.ylabel('Confirmed Cases', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

recovered = df['recovered'].sum()
active = df['active'].sum()
deaths = df['deaths'].sum()

totals = [recovered, active, deaths]
labels = ['Recovered', 'Active', 'Deaths']
colors = ['green', 'blue', 'red']

plt.figure(figsize=(8,8))
plt.pie(
    totals, 
    labels=labels, 
    colors=colors, 
    autopct='%1.1f%%', 
    shadow=True, 

)

plt.title('COVID-19 Status in India', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()
